# %% [markdown]
# # 03 Validation Results
# Run correlation and model validation analyses on the CATEM prototype.

# %%
from src.data_loader import load_data
from src.catem_scoring import compute_catem_scores
from src.validation import correlation_matrix, linear_regression_summary, random_forest_importance
df = load_data('../data/synthetic/catem_sample_data.csv')
score_df = compute_catem_scores(df)
corr = correlation_matrix(score_df, [
    'catem_score',
    'presence_score',
    'embodiment_score',
    'workload_score',
    'behavior_score',
    'system_stability_score'
])
corr
