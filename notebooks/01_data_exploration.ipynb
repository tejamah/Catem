# %% [markdown]
# # 01 Data Exploration
# Explore the synthetic CATEM dataset and understand variable distributions.

# %%
import pandas as pd
from src.data_loader import load_data
df = load_data('../data/synthetic/catem_sample_data.csv')
df.head()
